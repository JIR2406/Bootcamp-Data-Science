# %% [markdown]
# En este notebook hablaremos acerca del metodo 'melt' de pandas, el cual nos permite transformar un DataFrame de formato ancho a formato largo.
#
# En general loa datos con formato ancho son mas faciles de leer qie los con formato largo.
#
# El metodo de fusion nos permite despivotar o cambiar el formato de nuestro conjunto de dato.

# %%
import pandas as pd

movies = pd.read_csv('../../data/TMDB_movie_dataset_v11.csv')

movies.head(3)
# Out:
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
#
#     original_title                                           overview  \
# 0        Inception  Cobb, a skilled thief who commits corporate es...
# 1     Interstellar  The adventures of a group of explorers who mak...
# 2  The Dark Knight  Batman raises the stakes in his war on crime. ...
#
#   popularity                       poster_path  \
# 0     83.952  /oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg
# ...

# %%
# El metodo melt nos permite transformar un DataFrame de formato ancho a formato largo.
# En este caso, vamos a transformar el DataFrame de peliculas para que cada fila sea una
# pelicula y cada columna sea un atributo de la pelicula.
movies_melted = movies.melt(id_vars=['id', 'title'])
movies_melted.head(10)
# Out:
#        id                    title      variable  value
# 0   27205                Inception  vote_average  8.364
# 1  157336             Interstellar  vote_average  8.417
# 2     155          The Dark Knight  vote_average  8.512
# 3   19995                   Avatar  vote_average  7.573
# 4   24428             The Avengers  vote_average   7.71
# 5  293660                 Deadpool  vote_average  7.606
# 6  299536   Avengers: Infinity War  vote_average  8.255
# 7     550               Fight Club  vote_average  8.438
# 8  118340  Guardians of the Galaxy  vote_average  7.906
# 9     680             Pulp Fiction  vote_average  8.488

# %%
# Selecciona las columnas a derretir (todas excepto id, title y release_date)
value_vars = [col for col in movies.columns if col not in ['id', 'title', 'release_date']]

movies_melted = movies.melt(id_vars=['id', 'title', 'release_date'], value_vars=value_vars, var_name='variable', value_name='valor')
movies_melted.head(10)
# Out:
#        id                    title release_date      variable  valor
# 0   27205                Inception   2010-07-15  vote_average  8.364
# 1  157336             Interstellar   2014-11-05  vote_average  8.417
# 2     155          The Dark Knight   2008-07-16  vote_average  8.512
# 3   19995                   Avatar   2009-12-15  vote_average  7.573
# 4   24428             The Avengers   2012-04-25  vote_average   7.71
# 5  293660                 Deadpool   2016-02-09  vote_average  7.606
# 6  299536   Avengers: Infinity War   2018-04-25  vote_average  8.255
# 7     550               Fight Club   1999-10-15  vote_average  8.438
# 8  118340  Guardians of the Galaxy   2014-07-30  vote_average  7.906
# 9     680             Pulp Fiction   1994-09-10  vote_average  8.488
