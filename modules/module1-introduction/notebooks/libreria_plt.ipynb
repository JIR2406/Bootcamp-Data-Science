# %% [markdown]
# # Introducción a Matplotlib
#
# Matplotlib es una de las bibliotecas más utilizadas en Python para la visualización de datos. Su función principal es permitir la creación de gráficos y visualizaciones de alta calidad, facilitando la exploración y comunicación de los datos que obtenemos como científicos de datos (DS).
#
# ## ¿Qué hace Matplotlib?
#
# - Permite crear gráficos de líneas, barras, dispersión, histogramas, entre muchos otros.
# - Facilita la personalización de gráficos (colores, etiquetas, leyendas, títulos).
# - Permite guardar los gráficos en diferentes formatos (PNG, PDF, SVG, etc.).
# - Es compatible con otras bibliotecas como NumPy y pandas.
#
# ## ¿Cómo se importa?
#
# Para comenzar a utilizar Matplotlib, normalmente se importa el módulo `pyplot` de la siguiente manera:
#
# ```python
# import matplotlib.pyplot as plt
# ```
#
#
# ## Funciones principales de `pyplot`
#
# | Función                | Descripción                                         |
# |------------------------|-----------------------------------------------------|
# | `plt.plot()`           | Grafica líneas o puntos conectados                  |
# | `plt.scatter()`        | Grafica puntos de dispersión                        |
# | `plt.bar()`            | Grafica barras verticales                           |
# | `plt.hist()`           | Grafica histogramas                                 |
# | `plt.xlabel()`         | Añade etiqueta al eje X                             |
# | `plt.ylabel()`         | Añade etiqueta al eje Y                             |
# | `plt.title()`          | Añade título al gráfico                             |
# | `plt.legend()`         | Añade leyenda al gráfico                            |
# | `plt.show()`           | Muestra el gráfico en pantalla                      |
#
# Con Matplotlib podrás crear visualizaciones efectivas para analizar y compartir tus datos.

# %%
# Un pequeño ejemplo de un gráfico de líneas con `pyplot`:

"""
El grafico de dispersion resultante simplemente traza todos los puntos
de datos individualmente, sin conectar los puntos con líneas.

"""

import matplotlib.pyplot as plt

year = [1950,1970,1990,2010]
pop = [2.519, 3.692, 5.323, 6.972]

plt.scatter(year, pop)
plt.show()

# %% [markdown]
# # Diagrama de dispersión (Scatter Plot)
#
# Cuando tienes una escala de tiempo a lo largo del eje horizontal, el **gráfico de líneas** es tu mejor aliado. Sin embargo, en muchos otros casos —como cuando intentas evaluar si existe una correlación entre dos variables— el **diagrama de dispersión** (scatter plot) es la mejor opción.
#
# Un diagrama de dispersión permite visualizar la relación entre dos variables numéricas. Cada punto representa una observación individual.
#
# ## Ejemplo básico con Python
#
# A continuación se muestra cómo construir un gráfico de dispersión utilizando `matplotlib`:
#
# ```python
# import matplotlib.pyplot as plt
#
# # Supongamos que tienes dos listas o arrays: x e y
# # x = [valores para la variable 1]
# # y = [valores para la variable 2]
#
# plt.scatter(x, y)         # Crea el diagrama de dispersión
# plt.xlabel('Variable X')  # Etiqueta del eje X
# plt.ylabel('Variable Y')  # Etiqueta del eje Y
# plt.title('Diagrama de dispersión entre X y Y')
# plt.show()                # Muestra el gráfico
# ```
#
# ## Caso práctico: GDP vs Esperanza de Vida
#
# Supón que tienes datos de **PIB per cápita** (`gdp_cap`) y **esperanza de vida** (`life_exp`) de distintos países para el año 2007. Un diagrama de dispersión te permite analizar si existe alguna relación entre estas variables.
#
# ```python
# plt.scatter(gdp_cap, life_exp)
# plt.xlabel('PIB per cápita (USD)')
# plt.ylabel('Esperanza de vida (años)')
# plt.title('PIB vs Esperanza de vida (2007)')
# plt.show()
# ```
#
# - **Observa**: Si los puntos tienden a subir juntos (patrón ascendente), indica correlación positiva; si bajan juntos, correlación negativa; si están dispersos, poca o ninguna relación.
#
# > De nuevo, recuerda que el paquete `matplotlib.pyplot` está disponible como `plt`.
#
# ---
#
# **Resumen:**
# Utiliza gráficos de líneas para visualizar tendencias en el tiempo, y diagramas de dispersión para comparar dos variables y buscar posibles relaciones entre ellas.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generamos 50 años equidistantes entre 1950 y 2024
np.random.seed(42)  # Para reproducibilidad
year = np.linspace(1950, 2024, 50)

# Población base: crecimiento exponencial suavizado + ruido aleatorio
pop_base = 2.5 * np.exp(0.018 * (year - 1950))  # Crecimiento simulando datos reales
ruido = np.random.normal(0, 0.15, size=year.shape)  # Ruido para la dispersión
pop = pop_base + ruido

plt.scatter(year, pop)
plt.xlabel('Año')
plt.ylabel('Población (miles de millones)')
plt.title('Crecimiento de la población mundial (con dispersión, 50 datos)')
plt.show()

# %% [markdown]
# # Visualización de datos: Histograma
#
# El **histograma** es una herramienta muy útil para explorar y entender la distribución de los datos. Permite observar la frecuencia de aparición de los valores dentro de distintos rangos (bins), ayudando a identificar patrones, tendencias o valores atípicos en una variable numérica.
#
# A continuación, se muestra un ejemplo sencillo de cómo crear un histograma en Python utilizando `matplotlib`:
#
# ```python
# import matplotlib.pyplot as plt
#
# # Lista de valores a analizar
# values = [0, 0.6, 1.4, 1.6, 2.2, 2.5, 2.6, 3.2, 3.5, 3.9, 4.2, 6]
#
# # Creamos un histograma con 3 bins (barras)
# plt.hist(values, bins=3, edgecolor='black')
#
# # Añadimos título y etiquetas para mayor claridad
# plt.title('Histograma de ejemplo')
# plt.xlabel('Valores')
# plt.ylabel('Frecuencia')
#
# # Mostramos el gráfico
# plt.show()
# ```
#
# **¿Qué hace este código?**
# - **Genera un histograma** de los valores en la lista `values`.
# - **Divide los datos en 3 grupos** (bins), mostrando cuántos valores caen en cada rango.
# - **Añade etiquetas** para una mejor interpretación del gráfico.
#
# > Los histogramas son ideales para identificar la forma de la distribución (simétrica, sesgada, bimodal, etc.) y detectar posibles valores atípicos.

# %%
import matplotlib.pyplot as plt

values = [0,0.6,1.4,1.6,2.2,2.5,2.6,3.2,3.5,3.9,4.2,6]
plt.hist(values,bins = 3)
plt.show()

# %% [markdown]
# # Personalización de los gráficos
#
# La personalización de los gráficos es una parte fundamental para comunicar de manera efectiva la información contenida en tus datos. Existen diferentes tipos de gráficos y, para cada uno, puedes realizar un número prácticamente infinito de personalizaciones: cambiar colores, formas, etiquetas, ejes, estilos de línea, entre otros.
#
# La elección de estas personalizaciones depende tanto de las características de los datos como de la historia que quieres contar con ellos.
#
# A continuación, veremos un ejemplo con un gráfico de líneas utilizando `matplotlib` en Python:
#
# ```python
# import matplotlib.pyplot as plt
#
# # Datos de ejemplo
# year = [1950, 1951, 1952, 2100]
# pop = [2.258, 2.57, 2.62, 10.85]
#
# # Añadimos más datos al principio
# year = [1800, 1850, 1900] + year
# pop = [1.0, 1.262, 1.650] + pop
#
# plt.plot(year, pop)
#
# # Personalizaciones básicas
# plt.xlabel('Año')
# plt.ylabel('Población (en miles de millones)')
# plt.title('Proyecciones de la Población Mundial')
# plt.yticks([0, 2, 4, 6, 8, 10], ['0', '2B', '4B', '6B', '8B', '10B'])
# plt.show()
# ```
#
# En este ejemplo se personalizan:
#
# - Las etiquetas de los ejes (`xlabel`, `ylabel`)
# - El título del gráfico (`title`)
# - Los valores y etiquetas del eje Y (`yticks`)
#
# Puedes seguir explorando otras opciones para adaptar los gráficos a tus necesidades y mejorar la presentación de la información.

# %%
import matplotlib.pyplot as plt
year = [1950,1951,1952,2100]
pop = [2.258,2.57,2.62,10.85]

# Add more data
year = [1800,1850,1900] + year
pop = [1.0,1.262,1.650] + pop


plt.plot(year,pop)

plt.xlabel('Year')
plt.ylabel('Population')
plt.title('World Population Projections')
plt.yticks([0,2,4,6,8,10],['0','2B','4B','6B','8B','10B'])
plt.show()
