# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar el conjunto de datos
df = pd.read_csv('../../data/student-alcohol-consumption.csv')
print("Datos cargados correctamente:")
print(df.columns)
# Out:
# Datos cargados correctamente:
# Index(['Unnamed: 0', 'school', 'sex', 'age', 'famsize', 'Pstatus', 'Medu',
#        'Fedu', 'traveltime', 'failures', 'schoolsup', 'famsup', 'paid',
#        'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel',
#        'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2',
#        'G3', 'location', 'study_time'],
#       dtype='object')

# %%
ax = sns.countplot(data=df, x="age", hue="age", palette='Set1', legend=False) # Usar 'hue' para colorear por edad
ax.set_facecolor("white")
ax.set_xlabel('Edad')
ax.set_ylabel('Número de estudiantes')
plt.show()
